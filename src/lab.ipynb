# %%
from plotly import express as px

# %%
data = {
    "s":["ETH","BTC","LTC"],
    "v":[20,30,10]
}
fig = px.pie(data, values='v', names='s')
fig.show()

# %%
from ccxt import binance,okex5,bybit,bitget
binance_ex = binance({
    "options": {
        "defaultType": "future",
    },
})
binance_ex.load_markets()

#return rules
binance_ex.market('ETH/USDT')
# Out:
# {'id': 'ETHUSDT',
#  'symbol': 'ETH/USDT',
#  'base': 'ETH',
#  'quote': 'USDT',
#  'baseId': 'ETH',
#  'quoteId': 'USDT',
#  'active': True,
#  'type': 'future',
#  'linear': True,
#  'inverse': False,
#  'spot': False,
#  'swap': True,
#  'future': True,
#  'option': False,
#  'margin': False,
#  'contract': True,
#  'contractSize': 1.0,
#  'expiry': None,
#  'expiryDatetime': None,
#  'optionType': None,
#  'strike': None,
#  'settle': 'USDT',
#  'settleId': 'USDT',
#  'precision': {'amount': 3, 'price': 2, 'base': 8, 'quote': 8},
#  'limits': {'amount': {'min': 0.001, 'max': 10000.0},
#   'price': {'min': 39.86, 'max': 306177.0},
#   'cost': {'min': 5.0, 'max': None},
#   'leverage': {'min': None, 'max': None},
#   'market': {'min': 0.001, 'max': 2000.0}},
#  'info': {'symbol': 'ETHUSDT',
#   'pair': 'ETHUSDT',
#   'contractType': 'PERPETUAL',
#   'deliveryDate': '4133404800000',
#   'onboardDate': '1569398400000',
#   'status': 'TRADING',
#   'maintMarginPercent': '2.5000',
# ...

# %%
binance_ex.load_trading_limits()
# Out:
# {'BTC/USDT': {'id': 'BTCUSDT',
#   'symbol': 'BTC/USDT',
#   'base': 'BTC',
#   'quote': 'USDT',
#   'baseId': 'BTC',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'future',
#   'linear': True,
#   'inverse': False,
#   'spot': False,
#   'swap': True,
#   'future': True,
#   'option': False,
#   'margin': False,
#   'contract': True,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': 'USDT',
#   'settleId': 'USDT',
#   'precision': {'amount': 3, 'price': 1, 'base': 8, 'quote': 8},
#   'limits': {'amount': {'min': 0.001, 'max': 1000.0},
#    'price': {'min': 556.8, 'max': 4529764.0},
#    'cost': {'min': 5.0, 'max': None},
#    'leverage': {'min': None, 'max': None},
#    'market': {'min': 0.001, 'max': 120.0}},
#   'info': {'symbol': 'BTCUSDT',
#    'pair': 'BTCUSDT',
#    'contractType': 'PERPETUAL',
#    'deliveryDate': '4133404800000',
#    'onboardDate': '1569398400000',
# ...

# %%
okex5_ex = okex5({
    "options": {
        "defaultType": "swap",
        "fetchMarkets": ["swap"],
    },
})
okex5_ex.load_markets()
okex5_ex.symbols
# Out:
# ['1INCH/USD:1INCH',
#  '1INCH/USDT:USDT',
#  'AAVE/USDT:USDT',
#  'ADA/USD:ADA',
#  'ADA/USDT:USDT',
#  'AGLD/USDT:USDT',
#  'ALGO/USD:ALGO',
#  'ALGO/USDT:USDT',
#  'ALPHA/USDT:USDT',
#  'ANT/USDT:USDT',
#  'APE/USDT:USDT',
#  'API3/USDT:USDT',
#  'APT/USDT:USDT',
#  'AR/USDT:USDT',
#  'ATOM/USD:ATOM',
#  'ATOM/USDT:USDT',
#  'AVAX/USD:AVAX',
#  'AVAX/USDT:USDT',
#  'AXS/USDT:USDT',
#  'BADGER/USDT:USDT',
#  'BAL/USDT:USDT',
#  'BAND/USDT:USDT',
#  'BAT/USDT:USDT',
#  'BCH/USD:BCH',
#  'BCH/USDT:USDT',
#  'BICO/USDT:USDT',
#  'BLUR/USDT:USDT',
#  'BNB/USDT:USDT',
#  'BNT/USDT:USDT',
#  'BSV/USD:BSV',
#  'BSV/USDT:USDT',
#  'BTC/USD:BTC',
#  'BTC/USD:USDC',
#  'BTC/USDT:USDT',
#  'CEL/USDT:USDT',
#  'CELO/USDT:USDT',
#  'CFX/USDT:USDT',
#  'CHZ/USDT:USDT',
#  'COMP/USDT:USDT',
#  'CORE/USDT:USDT',
#  'CRO/USDT:USDT',
#  'CRV/USD:CRV',
#  'CRV/USDT:USDT',
#  'CSPR/USDT:USDT',
#  'CVC/USDT:USDT',
#  'DASH/USD:DASH',
#  'DASH/USDT:USDT',
#  'DOGE/USD:DOGE',
#  'DOGE/USDT:USDT',
# ...

# %%
bitget_ex = bitget({
    "options": {
        "defaultType": "swap",
        "fetchMarkets": ["swap"],
    },
})
bitget_ex.load_markets()
# Out:
# {'BTC/USDT:USDT': {'id': 'BTCUSDT_UMCBL',
#   'symbol': 'BTC/USDT:USDT',
#   'base': 'BTC',
#   'quote': 'USDT',
#   'baseId': 'BTC',
#   'quoteId': 'USDT',
#   'active': None,
#   'type': 'swap',
#   'linear': True,
#   'inverse': False,
#   'spot': False,
#   'swap': True,
#   'future': False,
#   'option': False,
#   'margin': False,
#   'contract': True,
#   'contractSize': 0.001,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': 'USDT',
#   'settleId': 'USDT',
#   'precision': {'amount': 0.001, 'price': 0.5},
#   'limits': {'amount': {'min': 0.001, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None},
#    'leverage': {'min': None, 'max': None}},
#   'info': {'symbol': 'BTCUSDT_UMCBL',
#    'makerFeeRate': '0.0002',
#    'takerFeeRate': '0.0006',
#    'feeRateUpRatio': '0.005',
#    'openCostUpRatio': '0.01',
#    'quoteCoin': 'USDT',
#    'baseCoin': 'BTC',
# ...

# %%
bybit_ex = bybit({
    "options": {    
        "defaultType": "swap",
        "fetchMarkets": ["swap"],
    },
})
bybit_ex.load_markets()
# Out:
# {'10000NFT/USDT:USDT': {'id': '10000NFTUSDT',
#   'symbol': '10000NFT/USDT:USDT',
#   'base': '10000NFT',
#   'quote': 'USDT',
#   'baseId': '10000NFT',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'swap',
#   'linear': True,
#   'inverse': False,
#   'spot': False,
#   'swap': True,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': True,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': 'USDT',
#   'settleId': 'USDT',
#   'precision': {'amount': 10.0, 'price': 5e-06},
#   'limits': {'amount': {'min': 10.0, 'max': 445100.0},
#    'price': {'min': 5e-06, 'max': 9.99999},
#    'cost': {'min': None, 'max': None},
#    'leverage': {'min': 1.0, 'max': 12.5}},
#   'info': {'symbol': '10000NFTUSDT',
#    'contractType': 'LinearPerpetual',
#    'status': 'Trading',
#    'baseCoin': '10000NFT',
#    'quoteCoin': 'USDT',
#    'launchTime': '1643007175000',
# ...
